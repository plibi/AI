# %%
# 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 데이터 로드 후 확인
PATH = '/content/drive/MyDrive/Dacon/dataset/'
file_name = 'train.csv'

df = pd.read_csv(PATH+file_name)
df.head()
# Out:
#    id                                            reviews  target
# 0   0                                     조아요 처음구입 싸게햇어요       2
# 1   1  생각보다 잘 안돼요 매지 바른지 하루밖에 안됐는데ㅠㅠ 25천원가량 주고 사기 너무 ...       1
# 2   2  디자인은괜찮은데 상품이 금이가서 교환했는데 두번째받은상품도 까져있고 안쪽에 금이가져...       2
# 3   3  기전에 이 제품말고 이마트 트레이더스에서만 팔던 프리미엄 제품을 사용했었습니다. 샘...       2
# 4   4                                  튼튼하고 손목을 잘 받쳐주네요~       5

# %%
# 총 25000개 훈련 데이터
# reviews는 str타입의 리뷰텍스트, target은 int타입의 평점으로 구성
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       25000 non-null  int64
#  1   reviews  25000 non-null  object
#  2   target   25000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 586.1+ KB

# %%
# target의 분포를 살펴보자
df['target'].describe()
# Out:
# count    25000.000000
# mean         3.220000
# std          1.640642
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          5.000000
# max          5.000000
# Name: target, dtype: float64

# %%
# 디테일하게는 분포의 차이가 있지만
# 부정인 1,2점 => 12500개
# 긍정인 4,5점 => 12500개로 동일
df['target'].value_counts()
# Out:
# 5    10000
# 2     8000
# 1     4500
# 4     2500
# Name: target, dtype: int64

# %%
# 결측치 없음
df.isna().sum()
# Out:
# id         0
# reviews    0
# target     0
# dtype: int64

# %%
# 중복되는 리뷰 1개
df['reviews'].duplicated().sum()
# Out:
# 1

# %%
# 확인
df[df['reviews'].duplicated()]
# Out:
#           id             reviews  target
# 12562  12562  배송이느려 페인트칠 다하고 왔네요       1

# %%
# 12479번, 12562번은 중복되는 리뷰지만 target은 2, 1로 다름
# => 제거하지말고 사용하도록 하자
df[df['reviews'].str.contains('페인트칠')]
# Out:
#           id                                            reviews  target
# 12479  12479                                 배송이느려 페인트칠 다하고 왔네요       2
# 12562  12562                                 배송이느려 페인트칠 다하고 왔네요       1
# 13979  13979  부모님집 도배하면서 문도 너무 오래되서 페인트칠 하면서 문고리도 바꿨습니다! 문고리...       5
# 20733  20733          재구매 페인트칠하고 아직 가구는 못만들규 있어요 그래도 나무 사기 만족해요       5

# %%
# 이상한 리뷰가 있을까?
# 역시나 너무 예쁘고 만족해요~ => 2점(부정)
df[df['reviews'].str.contains('너무')]
# Out:
#           id                                            reviews  target
# 1          1  생각보다 잘 안돼요 매지 바른지 하루밖에 안됐는데ㅠㅠ 25천원가량 주고 사기 너무 ...       1
# 13        13                                    너무 잘사용했어요 감사합니다       4
# 20        20                                   강추해요 너무 잘쓰고 있어ㅇᆢ       5
# 23        23                                   재구매 사이즈가 너무 작습니다       2
# 28        28                   세척이 잘안되요. 그리고 냄새가 너무 찐해서 머리가 아파요       2
# ...      ...                                                ...     ...
# 24980  24980                                   역시나 너무 예쁘고 만족해요~       2
# 24982  24982                       크기가 큰 4구로 배송됐어요. 너무 달고 맛있어요!       5
# 24989  24989  일요일인데 진짜 5분 안에 옵니다!! [ 오리AND닭 푸드 ]에서 오리고기, 춘천 ...       5
# 24992  24992                                       너무 작아요. 불쳔해요       2
# 24995  24995                일단향이너무너무좋은데지속력만좋다면좋겠지만..워낙저렴해그래도좋아여       5
#
# [3339 rows x 3 columns]

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 19.8 MB/s
# ...
#      |████████████████████████████████| 596 kB 48.9 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 52.0 MB/s
# ...
#      |████████████████████████████████| 101 kB 12.4 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# Huggingface
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("jason9693/SoongsilBERT-base-beep")

model = AutoModelForSequenceClassification.from_pretrained("jason9693/SoongsilBERT-base-beep")
